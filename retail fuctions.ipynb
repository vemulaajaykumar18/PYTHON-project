# %%
# Core Libraries
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Settings (makes charts cleaner)
sns.set(style="whitegrid")
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df = pd.read_csv("/content/walmart..orders.csv")

# %% [markdown]
# # **Structural Inspection Operations**

# %% [markdown]
# 1. df.head() -top rows
# 2. df.tail()  - bottom rows
# 3. df.sample(5) randam data

# %%
df.head()
# Out:
#    Order_ID Customer_ID  Order_Date Region Product_Category Customer_Segment  \
# 0         1    CUST3818  2024-08-18  North         Clothing        Corporate
# 1         2    CUST9689  2024-06-19  South           Beauty      Home Office
# 2         3    CUST9147  2024-11-21   West           Sports        Corporate
# 3         4    CUST7938  2024-07-19  North         Clothing         Consumer
# 4         5    CUST5127  2024-10-28  South   Home & Kitchen         Consumer
#
#    Quantity  Unit_Price  Discount_Rate  Revenue    Cost  Profit Payment_Method
# 0         5      300.68           0.27  1097.48  768.29  329.19    Credit Card
# 1         9       32.89           0.02   290.09  179.33  110.76     Debit Card
# 2         5      345.61           0.25  1296.04 1022.60  273.44    Credit Card
# 3         1      444.50           0.06   417.83  280.99  136.84            UPI
# 4         5       65.13           0.21   257.26  151.90  105.36    Credit Card

# %%
df.tail()
# Out:
#       Order_ID Customer_ID  Order_Date Region Product_Category  \
# 9995      9996    CUST9137  2024-06-30   West           Beauty
# 9996      9997    CUST3663  2024-08-21   East         Clothing
# 9997      9998    CUST2546  2024-04-05  South         Clothing
# 9998      9999    CUST9750  2024-05-13   East           Sports
# 9999     10000    CUST8377  2024-06-12  North      Electronics
#
#      Customer_Segment  Quantity  Unit_Price  Discount_Rate  Revenue    Cost  \
# 9995      Home Office         3      210.14           0.09   573.68  422.90
# 9996      Home Office         3      332.67           0.13   868.27  544.27
# 9997        Corporate         5      440.10           0.01  2178.49 1464.86
# 9998      Home Office        10      303.63           0.17  2520.13 1455.60
# 9999         Consumer         8      423.22           0.30  2370.03 1831.04
#
#       Profit    Payment_Method
# 9995  150.78       Credit Card
# 9996  324.00       Credit Card
# 9997  713.63       Net Banking
# ...

# %%
df.sample(5)
# Out:
#       Order_ID Customer_ID  Order_Date Region Product_Category  \
# 1548      1549    CUST6078  2024-12-21   East   Home & Kitchen
# 3882      3883    CUST7277  2024-06-29  North           Beauty
# 6498      6499    CUST2605  2024-05-31   West      Electronics
# 576        577    CUST9158  2024-03-21   West         Clothing
# 6201      6202    CUST4828  2024-01-26   East   Home & Kitchen
#
#      Customer_Segment  Quantity  Unit_Price  Discount_Rate  Revenue    Cost  \
# 1548         Consumer         1      310.93           0.13   270.51  167.23
# 3882        Corporate         9      315.52           0.03  2754.49 1511.62
# 6498        Corporate         9      428.38           0.05  3662.65 1871.58
# 576       Home Office         1      493.21           0.07   458.69  349.99
# 6201        Corporate         4      460.19           0.07  1711.91 1151.52
#
#       Profit    Payment_Method
# 1548  103.28       Credit Card
# 3882 1242.87               UPI
# 6498 1791.07  Cash on Delivery
# ...

# %% [markdown]
# ## **Purpose → Structure & datatypes.**

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          10000 non-null  int64
#  1   Customer_ID       10000 non-null  object
#  2   Order_Date        10000 non-null  object
#  3   Region            10000 non-null  object
#  4   Product_Category  10000 non-null  object
#  5   Customer_Segment  10000 non-null  object
#  6   Quantity          10000 non-null  int64
#  7   Unit_Price        10000 non-null  float64
#  8   Discount_Rate     10000 non-null  float64
#  9   Revenue           10000 non-null  float64
#  10  Cost              10000 non-null  float64
#  11  Profit            10000 non-null  float64
#  12  Payment_Method    10000 non-null  object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 1015.8+ KB

# %%
df.describe()
# Out:
#        Order_ID  Quantity  Unit_Price  Discount_Rate  Revenue     Cost  \
# count  10000.00  10000.00    10000.00       10000.00 10000.00 10000.00
# mean    5000.50      5.51      255.51           0.15  1195.24   776.29
# std     2886.90      2.86      140.83           0.09   979.59   651.47
# min        1.00      1.00       10.00           0.00     8.59     5.74
# 25%     2500.75      3.00      132.78           0.08   396.30   255.59
# 50%     5000.50      5.00      255.00           0.15   924.37   595.48
# 75%     7500.25      8.00      377.89           0.23  1775.84  1141.33
# max    10000.00     10.00      499.94           0.30  4972.10  3911.52
#
#         Profit
# count 10000.00
# mean    418.95
# std     368.42
# min       1.97
# 25%     131.78
# 50%     311.39
# 75%     606.85
# max    2292.42

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Order_Date', 'Region', 'Product_Category',
#        'Customer_Segment', 'Quantity', 'Unit_Price', 'Discount_Rate',
#        'Revenue', 'Cost', 'Profit', 'Payment_Method'],
#       dtype='object')

# %% [markdown]
# # **Missing Value Operations**

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Customer_ID         0
# Order_Date          0
# Region              0
# Product_Category    0
# Customer_Segment    0
# Quantity            0
# Unit_Price          0
# Discount_Rate       0
# Revenue             0
# Cost                0
# Profit              0
# Payment_Method      0
# dtype: int64

# %%
(df.isnull().mean() * 100).sort_values(ascending=False)
# Out:
# Order_ID           0.00
# Customer_ID        0.00
# Order_Date         0.00
# Region             0.00
# Product_Category   0.00
# Customer_Segment   0.00
# Quantity           0.00
# Unit_Price         0.00
# Discount_Rate      0.00
# Revenue            0.00
# Cost               0.00
# Profit             0.00
# Payment_Method     0.00
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_ID, Order_Date, Region, Product_Category, Customer_Segment, Quantity, Unit_Price, Discount_Rate, Revenue, Cost, Profit, Payment_Method]
# Index: []

# %% [markdown]
# # **Filtering & Conditional Selection**

# %%
df[df['Region'] == 'North']
# Out:
#       Order_ID Customer_ID  Order_Date Region Product_Category  \
# 0            1    CUST3818  2024-08-18  North         Clothing
# 3            4    CUST7938  2024-07-19  North         Clothing
# 5            6    CUST4834  2024-10-22  North           Sports
# 15          16    CUST6518  2024-03-24  North           Sports
# 16          17    CUST2327  2024-11-30  North           Sports
# ...        ...         ...         ...    ...              ...
# 9983      9984    CUST2430  2024-12-07  North         Clothing
# 9990      9991    CUST9172  2024-03-14  North      Electronics
# 9991      9992    CUST3165  2024-10-05  North           Beauty
# 9992      9993    CUST3893  2024-05-07  North         Clothing
# 9999     10000    CUST8377  2024-06-12  North      Electronics
#
#      Customer_Segment  Quantity  Unit_Price  Discount_Rate  Revenue    Cost  \
# 0           Corporate         5      300.68           0.27  1097.48  768.29
# ...

# %%
df[df['Revenue'] > 1000]
# Out:
#       Order_ID Customer_ID  Order_Date Region Product_Category  \
# 0            1    CUST3818  2024-08-18  North         Clothing
# 2            3    CUST9147  2024-11-21   West           Sports
# 6            7    CUST4649  2024-05-01   West      Electronics
# 7            8    CUST3844  2024-08-11  South         Clothing
# 10          11    CUST6670  2024-10-08   West      Electronics
# ...        ...         ...         ...    ...              ...
# 9992      9993    CUST3893  2024-05-07  North         Clothing
# 9993      9994    CUST9173  2024-02-19  South         Clothing
# 9997      9998    CUST2546  2024-04-05  South         Clothing
# 9998      9999    CUST9750  2024-05-13   East           Sports
# 9999     10000    CUST8377  2024-06-12  North      Electronics
#
#      Customer_Segment  Quantity  Unit_Price  Discount_Rate  Revenue    Cost  \
# 0           Corporate         5      300.68           0.27  1097.48  768.29
# ...

# %%
 cd =df[(df['Profit'] > 100) & (df['Discount_Rate'] > 0.2)]
 cd.Profit.sum()
# Out:
# np.float64(1146306.27)

# %% [markdown]
# # **Sorting Operations***

# %%
df.sort_values(by='Revenue', ascending=False)
# Out:
#       Order_ID Customer_ID  Order_Date Region Product_Category  \
# 4136      4137    CUST7122  2024-09-27  South   Home & Kitchen
# 2170      2171    CUST8033  2024-08-05  North      Electronics
# 9910      9911    CUST9994  2024-06-25   East   Home & Kitchen
# 3814      3815    CUST1393  2024-09-12   East      Electronics
# 9807      9808    CUST8086  2024-12-12  South           Beauty
# ...        ...         ...         ...    ...              ...
# 6307      6308    CUST9767  2024-05-28   East           Sports
# 878        879    CUST1342  2024-11-13   West         Clothing
# 2888      2889    CUST7682  2024-08-28   West           Beauty
# 4053      4054    CUST5248  2024-12-27   West           Beauty
# 644        645    CUST8228  2024-08-05  South         Clothing
#
#      Customer_Segment  Quantity  Unit_Price  Discount_Rate  Revenue    Cost  \
# 4136      Home Office        10      497.21           0.00  4972.10 3911.52
# ...

# %%
df.sort_values(by=['Region','Profit'])
# Out:
#       Order_ID Customer_ID  Order_Date Region Product_Category  \
# 929        930    CUST6764  2024-11-15   East      Electronics
# 6307      6308    CUST9767  2024-05-28   East           Sports
# 95          96    CUST8945  2024-11-14   East         Clothing
# 6196      6197    CUST4664  2024-09-17   East           Beauty
# 8907      8908    CUST8195  2024-06-01   East   Home & Kitchen
# ...        ...         ...         ...    ...              ...
# 3263      3264    CUST8773  2024-09-20   West   Home & Kitchen
# 7630      7631    CUST3971  2024-05-08   West         Clothing
# 6092      6093    CUST6378  2024-03-20   West           Beauty
# 3898      3899    CUST1036  2024-12-31   West   Home & Kitchen
# 673        674    CUST5560  2024-09-17   West   Home & Kitchen
#
#      Customer_Segment  Quantity  Unit_Price  Discount_Rate  Revenue    Cost  \
# 929         Corporate         2       11.28           0.26    16.69   13.15
# ...

# %% [markdown]
# # **Aggregation Operations**

# %%
df.groupby('Region')['Revenue'].sum()
# Out:
# Region
# East    2987841.70
# North   3038232.15
# South   2942635.95
# West    2983709.68
# Name: Revenue, dtype: float64

# %%
df.groupby('Product_Category')[['Revenue','Profit']].mean()
# Out:
#                   Revenue  Profit
# Product_Category
# Beauty            1216.37  423.73
# Clothing          1162.11  406.09
# Electronics       1222.16  429.02
# Home & Kitchen    1183.81  419.85
# Sports            1192.10  416.16

# %% [markdown]
# # ***Feature Engineering Operations***

# %%
df['Margin'] = df['Profit'] / df['Revenue']

# %%
df['Expected_Revenue'] = df['Quantity'] * df['Unit_Price']
df[['Revenue', 'Expected_Revenue']]
# Out:
#       Revenue  Expected_Revenue
# 0     1097.48           1503.40
# 1      290.09            296.01
# 2     1296.04           1728.05
# 3      417.83            444.50
# 4      257.26            325.65
# ...       ...               ...
# 9995   573.68            630.42
# 9996   868.27            998.01
# 9997  2178.49           2200.50
# 9998  2520.13           3036.30
# 9999  2370.03           3385.76
#
# [10000 rows x 2 columns]

# %%
df[['Revenue','Profit','Quantity']].corr()
# Out:
#           Revenue  Profit  Quantity
# Revenue      1.00    0.93      0.63
# Profit       0.93    1.00      0.59
# Quantity     0.63    0.59      1.00

# %% [markdown]
# # **Revenue Distribution**

# %%
sns.histplot(df['Revenue'], kde=True)
# Out:
# <Axes: xlabel='Revenue', ylabel='Count'>

# %% [markdown]
# # **Revenue Distribution**

# %%
sns.boxplot(x=df['Margin'])
# Out:
# <Axes: xlabel='Margin'>

# %%
df['Region'].value_counts()
# Out:
# Region
# North    2548
# East     2506
# West     2486
# South    2460
# Name: count, dtype: int64

# %%
corr = df[['Revenue','Profit','Discount_Rate']].corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
sns.scatterplot(x='Revenue', y='Profit', data=df)
plt.show()

# %%
df.groupby('Region')[['Revenue','Profit']].mean()
# Out:
#         Revenue  Profit
# Region
# East    1192.28  418.78
# North   1192.40  419.36
# South   1196.19  419.10
# West    1200.21  418.55

# %%
ct = pd.crosstab(df['Region'], df['Payment_Method'])
ct
# Out:
# Payment_Method  Cash on Delivery  Credit Card  Debit Card  Net Banking  UPI
# Region
# East                         508          516         523          457  502
# North                        536          507         504          476  525
# South                        491          475         537          475  482
# West                         482          465         510          527  502

# %%
df[df['Revenue'] > df['Revenue'].quantile(0.99)]
# Out:
#       Order_ID Customer_ID  Order_Date Region Product_Category  \
# 41          42    CUST3866  2024-12-17  South   Home & Kitchen
# 61          62    CUST8473  2024-07-20  North         Clothing
# 73          74    CUST5198  2024-11-06   East      Electronics
# 102        103    CUST8363  2024-06-22  South   Home & Kitchen
# 137        138    CUST7758  2024-01-10   West         Clothing
# ...        ...         ...         ...    ...              ...
# 9749      9750    CUST7418  2024-08-27   West         Clothing
# 9807      9808    CUST8086  2024-12-12  South           Beauty
# 9878      9879    CUST1648  2024-06-18   West           Beauty
# 9910      9911    CUST9994  2024-06-25   East   Home & Kitchen
# 9964      9965    CUST4527  2024-05-15  South         Clothing
#
#      Customer_Segment  Quantity  Unit_Price  Discount_Rate  Revenue    Cost  \
# 41        Home Office        10      408.29           0.01  4042.07 3067.38
# ...

# %%
df['Margin'] = df['Profit'] / df['Revenue']
df['Margin']
# Out:
# 0      0.30
# 1      0.38
# 2      0.21
# 3      0.33
# 4      0.41
#        ...
# 9995   0.26
# 9996   0.37
# 9997   0.33
# 9998   0.42
# 9999   0.23
# Name: Margin, Length: 10000, dtype: float64

# %%
sns.countplot(x='Region', data=df)
plt.show()
